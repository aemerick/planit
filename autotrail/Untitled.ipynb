# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import largetestrun as ltr

# %%
fig, kde = ltr.make_plots()
# Out:
# Average Fractional error:  1.1054857068736252 0.9862931187421017
# Median Fractional error:  1.0749251245852338 0.934802420530767
# Max length of route  700

# %%
kde.fig.show()
# Out:
# /home/aemerick/anaconda3/envs/planit/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.
